# %%
import read_video
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x = read_video.read_video("/Users/BrittanyDorsey/Desktop/my-notebook/OrNet-Data/DsRed2-HeLa_10_26_Cell3.mov", first_only=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
x[1].shape
# Out:
# (512, 512)

# %%
plt.imshow(x[1])

# %%
y = read_video.read_video("/Users/BrittanyDorsey/Desktop/my-notebook/OrNet-Data/DsRed2-HeLa_4_5_LLO1_Cell0.mov", first_only=True)
# Out:
# /anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))

# %%
y[1].shape
# Out:
# (512, 512)

# %%
plt.imshow(y[1])
